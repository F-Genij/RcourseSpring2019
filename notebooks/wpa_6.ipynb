# %% [markdown]
# # WPA #6 - Plotting - Chapter 13

# %% [markdown]
# ## Hypothesis tests from a student survey

# %% [markdown]
# In this WPA, you'll analyze data from a *fictional* survey of 100 students.

# %% [markdown]
# ## Datafile description
#
# The data file has 100 rows and 12 columns. Here are the columns
#
# - `sex`: string. A string indicting the sex of the participant. "m" = male, "f" = female.
#
# - `age`: integer.  An integer indicating the age of the participant.
#
# - `major`: string. A string indicating the participant's major
#
# - `haircolor`: string. Hair color
#
# - `iq`: integer. P's score on an IQ test.
#
# - `country`: string. P's country of origin
#
# - `logic`: numeric. Amount of time it took for a participant to complete a logic problem. Smaller is better.
#
# - `siblings`: integer. How many siblings does the P have?
#
# - `multitasking`: integer. Participant's score on a multitasking task. Higher is better.
#
# - `partners`: integer. How many sexual partners has the participant had?
#
# - `marijuana`: binary. Has the participant ever tried marijuana? 0 = "no", 1 = "yes"
#
# - `risk`: binary. Would the person play a gamble with a 50% chance of losing 20CHF and a 50% chance of earning 20CHF? 0 means the participant would *not* play the gamble, 1 means they would

# %% [markdown]
# ## A. Data loading and preparation
#
# Open a new script and enter your name, date, and the wpa number at the top. Save the script in the `R` subfolder (situated in your R course project folder) as `wpa_6_LASTFIRST.R`, where LAST and FIRST are your last and first names.
#
# 2. Set your working directory using `setwd()` to your R course project directory.
#
# 3. The data are located in a `csv` file at https://raw.githubusercontent.com/laurafontanesi/RcourseSpring2019/master/data/data_wpa6.csv. Load them into R using `read.csv()` as a new object called `wpa6.df`. Note that you can directly use the URL to load them (without first downloading the file to your computer).
#
# 4. Using `write.csv()`, save the data as a `csv` file titled `data_wpa6.csv` into the `data` subfolder in your R course project folder.
#
# 5. Using `head()`, and `dim()` look at the dataset and make sure that it was loaded correctly. If the data don't look correct (i.e; if there isn't a header row and 100 rows and 12 columns), you didn't load it correctly!

# %% [markdown]
# ### APA style
# **For each hypothesis test you run this week I want you write a short answer (in commented code) reporting the answer to this hypothesis test.**
#
# **Assume an alpha level of 0.05 for all tests.**
#
# **Please include relevant statistics in your answer in APA style! If your p-value is less than .01, just write p < .01**
#
# **Chi-square: X(df) = XXX, p = YYY**
#
# **t-test: t(df) = XXX, p = YYY**
#
# **correlation test: r = XXX, t(df) = YYY, p = ZZZZ**

# %% [markdown]
# For example, here is some output with the appropriate apa conclusion:

# %%
library(yarrr)

# Do pirates with headbands have different numbers of tattoos than those
#  who do not wear headbands?
t.test(tattoos ~ headband, 
       data = pirates)

print('Answer: Pirates with headbands have significantly more tattoos on average than those who do not wear headbands: t(146.73) = -19.31, p < .01')
# Out:
# Loading required package: jpeg
# Loading required package: BayesFactor
# Loading required package: coda
# Loading required package: Matrix
# ************
# Welcome to BayesFactor 0.9.12-4.2. If you have questions, please contact Richard Morey (richarddmorey@gmail.com).
#
# Type BFManual() to open the manual.
# ************
# Loading required package: circlize
# ========================================
# circlize version 0.4.6
# CRAN page: https://cran.r-project.org/package=circlize
# Github page: https://github.com/jokergoo/circlize
# Documentation: http://jokergoo.github.io/circlize_book/book/
#
# If you use it in published research, please cite:
# Gu, Z. circlize implements and enhances circular visualization
#   in R. Bioinformatics 2014.
# ========================================
#
# yarrr v0.1.5. Citation info at citation('yarrr'). Package guide at yarrr.guide()
# Email me at Nathaniel.D.Phillips.is@gmail.com
# 	Welch Two Sample t-test
#
# data:  tattoos by headband
# t = -19.313, df = 146.73, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -5.878101 -4.786803
# sample estimates:
#  mean in group no mean in group yes
#          4.699115         10.031567
# [1] "Answer: Pirates with headbands have significantly more tattoos on average than those who do not wear headbands: t(146.73) = -19.31, p < .01"

# %% [markdown]
# ## B. t-test(s)
#
# 1. Average IQ in the general population is 100. Do the participants have an IQ different from the general population? Answer this with a one-sample t-test.
#
# 2. A friend of yours claims that students have 2.5 siblings on average. Test this claim with a one-sample t-test.
#
# 3. Do students that have smoked marijuana have different IQ levels than those who have never smoked marijuana? Test this claim with a two-sample t-test (you can either use the vector or the formula notation for a t-test).

# %% [markdown]
# ## C. Correlation test(s)
#
# 1. Do students with higher multitasking skills tend to have more romantic partners than those with lower multitasking skills? Test this with a correlation test.
#
# 2. Do people with higher IQs perform faster on the logic test? Answer this question with a correlation test.

# %% [markdown]
# ## D. chi-square test(s)
#
# 1. Are some majors more popular than others? Answer this question with a one-sample chi-square test.
#
# 2. In general, were students more likely to take a risk than not? Answer this question with a one-sample chi-square test.
#
# 3. Is there a relationship between hair colour and students' academic major? Answer this with a two-sample chi-square test.

# %% [markdown]
# ## E. Anscombe's Famous data quartet
#
# In the next few questions, we'll explore Anscombe's famous data quartet. This famous dataset will show you the dangers of interpreting statistical tests (like a correlation test), without first plotting the data!

# %% [markdown]
# Run the following code to create the `anscombe.df` dataframe. This dataframe contains 4 datasets x1 and y1, x2 and y2, x3 and y3 and x4 and y4:

# %%
anscombe.df <- data.frame(x1 = c(10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5),
                          y1 = c(8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 4.68),
                          x2 = c(10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5),
                          y2 = c(9.14, 8.14, 8.74, 8.77, 9.26, 8.1, 6.13, 3.1, 9.13, 7.26, 4.74),
                          x3 = c(10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5),
                          y3 = c(7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73),
                          x4 = c(8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8),
                          y4 = c(6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.5, 5.56, 7.91, 6.89))

# %% [markdown]
# 1. Calculate the correlation between x1 and y1, x2 and y2, x3 and y3, and x4 and y4 separately (that is, what is the correlation between x1 and y? Now, what is the correlation between x2 and y2?, ...). What do you notice about the correlation values for each test?
#
# 2. Then, run the code below to generate a scatterplot of each data pair, what do you find?

# %%
# Plot the famous Anscombe quartet
layout(m=matrix(1:4, nrow=2, ncol=2)) # Create 2 x 2 plotting grid

for (i in 1:4) {   # Loop over datasets
 
  # Assign x and y for current value of i
  
  if (i == 1) {x <- anscombe.df$x1
               y <- anscombe.df$y1} 
  
  if (i == 2) {x <- anscombe.df$x2
               y <- anscombe.df$y2} 
  
  if (i == 3) {x <- anscombe.df$x3
               y <- anscombe.df$y3} 
  
  if (i == 4) {x <- anscombe.df$x4
               y <- anscombe.df$y4} 

  # Create plot
plot(x = x, y = y, pch = 21, main = paste("Anscombe",i, sep=" "), 
     bg = "orange", col = "red", 
     xlim = c(0, 20), ylim = c(0, 15))

 # Add regression line
abline(lm(y ~ x, 
          data = data.frame(y, x)),
       col = "blue", lty = 2)

# Add correlation test text
text(x = 3, y = 12, 
     labels = paste0("cor = ", round(cor(x, y), 2)))
  
}

layout(m=matrix(1, nrow=1, ncol=1)) # Reset plotting grid
# Out:
# Plot with title “Anscombe 4”

# %% [markdown]
# What you have just seen is the famous **Anscombe's quartet** a dataset designed to show you how important is to *always* plot your data before running a statistical test!!! You can see more at the wikipedia page here: https://en.wikipedia.org/wiki/Anscombe%27s_quartet

# %% [markdown]
# ## F. Pick the test (unless the question asks for a specific one):
#
# 1. Is there a relationship between whether a student has ever smoked marijuana and his/her decision to accept or reject the risky gamble?
#
# 2. Do males and females have different numbers of sexual partners on average?
#
# 3. Do males and females differ in how likely they are to have smoked marijuana?
#
# 4. Do people who have smoked marijuana have different logic scores on average than those who never have smoked marijuana?
#
# 5. Do people with higher iq scores tend to perform better on the logic test that those with lower iq scores?
#
# 6. Are Germans more likely than not to have tried marijuana? (Hint: this is a one-sample chi-square test but you'll need to use indexing)
#
# 7. Does the relationship between iq and multitasking differ between males and females? Test this by conducting two separate tests -- one for males and one for females. Do your conclusions differ?
#
# 8. Does the IQ of people with brown hair differ from blondes? (Hint: This is a two-sample t-test that requires you to use the `subset()` argument to tell R which two groups you want to compare)
#
# 9. Is there a relationship between age and IQ in men from Switzerland?
#
# 10. Do the people who chose the risky gamble and have smoked marijuana have more sexual partners than those who chose the risky gamble and have never smoked marijuana? Is there a relationship between smoking marijuana and number of sexual partners in the poeple who chose the risky gamble?
#
# 11. Among the people who chose the risky gamble *and* have never tried marijuana: Is there a relationship between IQ and performance on their logic test?

# %% [markdown]
# ### That's it! Now it's time to submit your assignment!
#
# Save and email your `wpa_6_LastFirst.R` file to me at [laura.fontanesi@unibas.ch](mailto:laura.fontanesi@unibas.ch).
#
# Assignments sent after Sunday 14th April will not be considered (to pass the course you have to hand in all assignments for each week).
